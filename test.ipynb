# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sultan Alabidi**
#
# *Data Science*

# %% [markdown]
# *I am interested in data science because i love data and secrets*

# %% [markdown]
# ### in cell 5 i will write a print code

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# this is the numbered list
# 1. Data analysis
# 2. data science
# 3. data mining
# this is the bulleted list
# - Data analysis
# - data science
# - data mining
#
# this is picture
# ![IMG_20170821_142746.jpg](attachment:IMG_20170821_142746.jpg)
